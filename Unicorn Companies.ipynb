# %%
import numpy as np
import pandas as pd
import seaborn as sns

import matplotlib.pyplot as plt
# %matplotlib inline
import cufflinks as cf
import plotly
from plotly.offline import iplot
import plotly.graph_objs as go
plotly.offline.init_notebook_mode(connected=True)
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.34.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
# ...

# %%
import pandas as pd
# Afficher toutes les colonnes
pd.set_option('display.max_columns', None)
# Ajuster la largeur maximale des colonnes
pd.set_option('display.max_colwidth', None)
# Afficher toutes les lignes
pd.set_option('display.max_rows', None)

# %%
data = pd.read_csv("Unicorn Companies .csv",low_memory=False)

# %%
data.head()
# Out:
#    index  company_id               company         city        country  \
# 0      0         189  Otto Bock HealthCare   Duderstadt        Germany
# 1      1         848            Matrixport          NaN      Singapore
# 2      2         556            Cloudinary  Santa Clara  United States
# 3      3         999                 PLACE   Bellingham  United States
# 4      4         396             candy.com     New York  United States
#
#        continent
# 0         Europe
# 1           Asia
# 2  North America
# 3  North America
# 4  North America

# %%
d = pd.read_csv("online_retail.csv")

# %%
d.head(100)
# Out:
#     index InvoiceNo StockCode                          Description  Quantity  \
# 0       0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1       1    536365     71053                  WHITE METAL LANTERN         6
# 2       2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3       3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4       4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5       5    536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 6       6    536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7       7    536366     22633               HAND WARMER UNION JACK         6
# 8       8    536366     22632            HAND WARMER RED POLKA DOT         6
# 9       9    536367     84879        ASSORTED COLOUR BIRD ORNAMENT        32
# 10     10    536367     22745           POPPY'S PLAYHOUSE BEDROOM          6
# ...

# %%
d["InvoiceDate"].max()
# Out:
# '12/6/10 9:58'

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12500 entries, 0 to 12499
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   index        12500 non-null  int64
#  1   InvoiceNo    12500 non-null  object
#  2   StockCode    12500 non-null  object
#  3   Description  12455 non-null  object
#  4   Quantity     12500 non-null  int64
#  5   InvoiceDate  12500 non-null  object
#  6   UnitPrice    12500 non-null  float64
#  7   CustomerID   8995 non-null   float64
#  8   Country      12500 non-null  object
# dtypes: float64(2), int64(2), object(5)
# memory usage: 879.0+ KB

# %%
d.describe()
# Out:
#               index      Quantity     UnitPrice    CustomerID
# count  12500.000000  12500.000000  12500.000000   8995.000000
# mean    6249.500000      7.480560      3.970551  15598.634686
# std     3608.583517     93.741676     17.227713   1745.712049
# min        0.000000  -9360.000000      0.000000  12395.000000
# 25%     3124.750000      1.000000      1.250000  14344.000000
# 50%     6249.500000      2.000000      2.510000  15646.000000
# 75%     9374.250000      6.000000      4.210000  17211.000000
# max    12499.000000   2880.000000    940.870000  18239.000000

# %%
data.drop(columns=["index",""])
# Out:
#    index  company_id               company         city        country  \
# 0      0         189  Otto Bock HealthCare   Duderstadt        Germany
# 1      1         848            Matrixport          NaN      Singapore
# 2      2         556            Cloudinary  Santa Clara  United States
# 3      3         999                 PLACE   Bellingham  United States
# 4      4         396             candy.com     New York  United States
#
#        continent
# 0         Europe
# 1           Asia
# 2  North America
# 3  North America
# 4  North America

# %%
data.drop(columns=["company_id"],inplace=True)

# %%
data.head()
# Out:
#                 company         city        country      continent
# 0  Otto Bock HealthCare   Duderstadt        Germany         Europe
# 1            Matrixport          NaN      Singapore           Asia
# 2            Cloudinary  Santa Clara  United States  North America
# 3                 PLACE   Bellingham  United States  North America
# 4             candy.com     New York  United States  North America

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1074 entries, 0 to 1073
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   company_id  1074 non-null   int64
#  1   company     1074 non-null   object
#  2   city        1058 non-null   object
#  3   country     1074 non-null   object
#  4   continent   1074 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 42.1+ KB

# %%
data.apply(lambda x : x.isnull().mean()*100)
# Out:
# company_id    0.000000
# company       0.000000
# city          1.489758
# country       0.000000
# continent     0.000000
# dtype: float64

# %%
total_missing = data.isnull().sum().sum()
total_values = data.size
percent_missing = (total_missing / total_values) * 100

print(f"Total valeurs nulles : {total_missing}")
print(f"Pourcentage global de valeurs nulles : {percent_missing:.2f}%")
# Out:
# Total valeurs nulles : 16
# Pourcentage global de valeurs nulles : 0.30%

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.groupby(["continent"]).count()["company"]
# Out:
# continent
# Africa             3
# Asia             310
# Europe           143
# North America    589
# Oceania            8
# South America     21
# Name: company, dtype: int64

# %%
data["continent"].value_counts()
# Out:
# continent
# North America    589
# Asia             310
# Europe           143
# South America     21
# Oceania            8
# Africa             3
# Name: count, dtype: int64

# %%
data
# Out:
#       company_id                           company                   city  \
# 0            189              Otto Bock HealthCare             Duderstadt
# 1            848                        Matrixport                    NaN
# 2            556                        Cloudinary            Santa Clara
# 3            999                             PLACE             Bellingham
# 4            396                         candy.com               New York
# 5            931                            HAYDON               Shanghai
# 6            364                            eDaili               Shanghai
# 7            732                       CoinTracker          San Francisco
# 8            906                           EcoFlow               Shenzhen
# 9             72                   DJI Innovations               Shenzhen
# 10           983                            Numbrs                 Zurich
# 11           898                         Darwinbox              Hyderabad
# ...

# %%
import pandas as pd
from sqlalchemy import create_engine

# Informations de connexion
host = "localhost"  # Remplace par l'adresse IP de l'ordinateur distant
port = 3306  # Port MySQL par défaut
database = "world"  # Remplace par le nom de ta base de données
username = "root"  # Nom d'utilisateur MySQL
password = "22205731"  # Mot de passe MySQL

# Créer une connexion SQLAlchemy
engine = create_engine(f"mysql+pymysql://{username}:{password}@{host}:{port}/{database}")

# %%
query = "SELECT * from city"

# Charger les données dans un DataFrame
df = pd.read_sql(query, engine)

# %%
df.head()
# Out:
#    ID            Name CountryCode       District  Population
# 0   1           Kabul         AFG          Kabol     1780000
# 1   2        Qandahar         AFG       Qandahar      237500
# 2   3           Herat         AFG          Herat      186800
# 3   4  Mazar-e-Sharif         AFG          Balkh      127800
# 4   5       Amsterdam         NLD  Noord-Holland      731200
